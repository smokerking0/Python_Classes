# %% [markdown]
# Operator, Operation and Operand

# %% [markdown]
# Arithmetic Operators

# %%
4 + 6
# Out:
# 10

# %%
9 - 1
# Out:
# 8

# %%
6 * 7
# Out:
# 42

# %%
12 / 3
# Out:
# 4.0

# %%
12 // 3  # floor divison
# Out:
# 4

# %%
13 % 3 # modulo
# Out:
# 1

# %%
4 ** 3
# Out:
# 64

# %% [markdown]
# Comparison Operators

# %%
4 == 3 # Equal to
# Out:
# False

# %%
5 == 5
# Out:
# True

# %%
2 != 6
# Out:
# True

# %%
6 > 3
# Out:
# True

# %%
6 < 3
# Out:
# False

# %%
5 >= 5
# Out:
# True

# %%
6 <= 3
# Out:
# False

# %% [markdown]
# Variable --> container that stores data in memory.

# %% [markdown]
# Rules for defining variables :
# - Must start with a letter or underscore.
# - Cannot use special charactes.
# - Case sensitive.
# - Cannot use reserved keywords.
# - No spaces allowed.
# - Can contain letter,number and underscore.

# %%
name = 'Rajesh'
age = 27

# %%
name
# Out:
# 'Rajesh'

# %%
age
# Out:
# 27

# %%
1r = 77
# Out:
#   File "/tmp/ipykernel_13259/575734525.py", line 1
#     1r = 77
#     ^
# SyntaxError: invalid decimal literal

# %%
a@bc = 55
# Out:
#   File "/tmp/ipykernel_13259/1101638627.py", line 1
#     a@bc = 55
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
A = 6

# %%
a = 3

# %%
A
# Out:
# 6

# %%
a
# Out:
# 3

# %%
name
# Out:
# 'Rajesh'

# %%
if = 55
# Out:
#   File "/tmp/ipykernel_13259/4261897127.py", line 1
#     if = 55
#        ^
# SyntaxError: invalid syntax

# %%
for = 33
# Out:
#   File "/tmp/ipykernel_13259/3744266668.py", line 1
#     for = 33
#         ^
# SyntaxError: invalid syntax

# %%
a
# Out:
# 3

# %%
a b = 33
# Out:
#   File "/tmp/ipykernel_13259/1458343016.py", line 1
#     a b = 33
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# Assignment Operator

# %%
balance = 100
balance
# Out:
# 100

# %%
balance += 50 # balance = balance + 50
balance
# Out:
# 150

# %%
balance -= 30 # balance = balance - 30
balance
# Out:
# 120

# %%
balance *= 2 # balance = balance * 2
balance
# Out:
# 240

# %%
balance /= 4 # balance = balance / 4

# %%
balance
# Out:
# 60.0
